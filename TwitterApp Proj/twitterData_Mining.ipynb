# %%
import tweepy
import json
import vincent
from tweepy import OAuthHandler

consumer_key = 'hWbAp36Ljlocg85l2bJJFOSae'
consumer_secret = 'Sl5wIHngxRTS2wfxMO2CO3mCQKa9PJocLdlvPOlpjVOIDFWaoX'
access_token = '870663008-fTe31tvBvdtaIyQKFTYXG7scrx1GZCGIhamMy2gV'
access_secret = 'JiQ8VLtp2shLYAgoFaTxBVuPF2caopZRRlIXPOuoPl6yK'
 
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth)


# the Twitter user who we want to get tweets from
name = "COVID_19_ZA"
# Number of tweets to pull
tweetCount = 10

# Calling the user_timeline function with our parameters
results = api.user_timeline(id=name, count=tweetCount)

# foreach through all tweets pulled
   # printing the text stored inside the tweet object
 
    
for status in tweepy.Cursor(api.home_timeline).items(5):
     print(json.dumps(tweet._json))
# Out:
# {"created_at": "Thu Aug 06 07:28:34 +0000 2020", "id": 1291274953380245504, "id_str": "1291274953380245504", "text": "Can #COVID19 be passed through breastfeeding?\n#WorldBreastfeedingWeek https://t.co/XZjOeUPZ28", "truncated": false, "entities": {"hashtags": [{"text": "COVID19", "indices": [4, 12]}, {"text": "WorldBreastfeedingWeek", "indices": [46, 69]}], "symbols": [], "user_mentions": [], "urls": [], "media": [{"id": 1291274949068492802, "id_str": "1291274949068492802", "indices": [70, 93], "media_url": "http://pbs.twimg.com/media/EeuHuYaWkAIGx__.jpg", "media_url_https": "https://pbs.twimg.com/media/EeuHuYaWkAIGx__.jpg", "url": "https://t.co/XZjOeUPZ28", "display_url": "pic.twitter.com/XZjOeUPZ28", "expanded_url": "https://twitter.com/COVID_19_ZA/status/1291274953380245504/photo/1", "type": "photo", "sizes": {"small": {"w": 680, "h": 661, "resize": "fit"}, "thumb": {"w": 150, "h": 150, "resize": "crop"}, "large": {"w": 1280, "h": 1245, "resize": "fit"}, "medium": {"w": 1200, "h":
# ...

# %%
 
word_freq = count_terms_only.most_common(5)
labels, freq = zip(*word_freq)
data = {'data': freq, 'x': labels}
bar = vincent.Bar(data, iter_idx='x')
bar.to_json('python.json')

time_chart = vincent.Line(COVID_19_ZA)
time_chart.axis_titles(x='Time', y='Freq')
time_chart.to_json('python.json')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-dac9392b9d29> in <module>
# ----> 1 word_freq = count_terms_only.most_common(5)
#       2 labels, freq = zip(*word_freq)
#       3 data = {'data': freq, 'x': labels}
#       4 bar = vincent.Bar(data, iter_idx='x')
#       5 bar.to_json('python.json')
#
# NameError: name 'count_terms_only' is not defined
